# %% [markdown]
# ### Synapse Dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for each dataset
data_original = [0.29, 0.2857, 0.25, 0.739, 0.258, 0.25]
data_2x = [0.0435, 0.069, 0.0426, 0.5, 0.125, 0.1316]
data_4x = [0.2045, 0.178, 0.098, 0.9259, 0.1458, 0.1458]
data_8x = [0.28, 0.26, 0.22, 0.75, 0.22, 0.2264]
data_16x = [0.2586, 0.2807, 0.2154, 0.75, 0.4074, 0.3571]

# X-coordinates for the conditions
conditions = ['Cond 1-2', 'Cond 1-3', 'Cond 1-4', 'Cond 2-3', 'Cond 2-4', 'Cond 3-4']
x = np.arange(len(conditions))

# Set the font properties
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12

# Create a plot with specified size
plt.figure(figsize=(6, 4))  # Adjusted height to accommodate legend below

# Plotting each dataset
plt.plot(x, data_original, marker='o', label='Original')
plt.plot(x, data_2x, marker='o', label='2x')
plt.plot(x, data_4x, marker='o', label='4x')
plt.plot(x, data_8x, marker='o', label='8x')
plt.plot(x, data_16x, marker='o', label='16x')

# Adding labels and title
plt.xlabel('Condition Pairs')
plt.ylabel('Values')
plt.title('Jaccard coefficient values pairwise Across Different Datasets')
plt.xticks(ticks=x, labels=conditions)

# Adding a legend below the plot
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.20), ncol=3, fontsize='small')

# Adjust layout for better fit and readability
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Camel Dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for each dataset
data_original = [0.2, 0.1395, 0.11, 0.133, 0.302, 0.267, 0.234, 0.656, 0.286, 0.375]
data_2x = [0.3617, 0.2245, 0.25, 0.1272, 0.283, 0.3077, 0.186, 0.82857, 0.08196, 0.081967]
data_4x = [0.1875, 0.2679, 0.2545, 0.1833, 0.1617, 0.203, 0.1127, 0.5, 0.213, 0.2]
data_8x = [0.2361, 0.1667, 0.1831, 0.16, 0.2794, 0.2608, 0.2676, 0.7826, 0.3077, 0.2879]
data_16x = [0.2603, 0.1125, 0.1235, 0.1585, 0.3286, 0.3014, 0.1512, 0.8776, 0.1852, 0.2099]

# X-coordinates for the conditions
conditions = ['Cond 1-2', 'Cond 1-3', 'Cond 1-4', 'Cond 1-5', 'Cond 2-3', 'Cond 2-4', 'Cond 2-5', 'Cond 3-4', 'Cond 3-5', 'Cond 4-5']
x = np.arange(len(conditions))

# Set the font properties
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12

# Create a plot with specified size
plt.figure(figsize=(8, 4))  # Adjusted width for more conditions

# Plotting each dataset
plt.plot(x, data_original, marker='o', label='Original')
plt.plot(x, data_2x, marker='o', label='2x')
plt.plot(x, data_4x, marker='o', label='4x')
plt.plot(x, data_8x, marker='o', label='8x')
plt.plot(x, data_16x, marker='o', label='16x')

# Adding labels and title
plt.xlabel('Condition Pairs')
plt.ylabel('Jaccard Coefficient Values')
plt.title('Jaccard Coefficient Values Pairwise Across Different Datasets')
plt.xticks(ticks=x, labels=conditions, rotation=45)

# Adding a legend below the plot
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -1), ncol=3, fontsize='small')

# Adjust layout for better fit and readability
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-7-ac1ec7b64cd8>:39: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### ant Dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for each dataset
data_original = [0.1176, 0.147, 0.051, 0.129, 0.2, 0.171, 0.2286, 0.233, 0.158, 0.1, 0.1875, 0.184, 0.1429, 0.237, 0.24]
data_2x = [0.1842, 0.1395, 0.186, 0.186, 0.1429, 0.222, 0.243, 0.278, 0.133, 0.25, 0.11, 0.1, 0.3, 0.14, 0.3256]
data_4x = [0.145, 0.167, 0.196, 0.192, 0.2264, 0.1228, 0.193, 0.2353, 0.22, 0.1724, 0.125, 0.1578, 0.218, 0.2727, 0.511]
data_8x = [0.26785, 0.196, 0.213, 0.3077, 0.3051, 0.1667, 0.2222, 0.2909, 0.2968, 0.1967, 0.1964, 0.2459, 0.3214, 0.2575, 0.4528]
data_16x = [0.246, 0.1095, 0.2083, 0.2754, 0.1625, 0.137, 0.1558, 0.1538, 0.1875, 0.2174, 0.2319, 0.1688, 0.2297, 0.2631, 0.469]

# X-coordinates for the conditions
conditions = ['Cond 1-2', 'Cond 1-3', 'Cond 1-4', 'Cond 1-5', 'Cond 1-6',
              'Cond 2-3', 'Cond 2-4', 'Cond 2-5', 'Cond 2-6', 'Cond 3-4',
              'Cond 3-5', 'Cond 3-6', 'Cond 4-5', 'Cond 4-6', 'Cond 5-6']
x = np.arange(len(conditions))

# Set the font properties
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12

# Create a plot with specified size
plt.figure(figsize=(10, 5))  # Adjusted width for more conditions

# Plotting each dataset
plt.plot(x, data_original, marker='o', label='Original')
plt.plot(x, data_2x, marker='o', label='2x')
plt.plot(x, data_4x, marker='o', label='4x')
plt.plot(x, data_8x, marker='o', label='8x')
plt.plot(x, data_16x, marker='o', label='16x')

# Adding labels and title
plt.xlabel('Condition Pairs')
plt.ylabel('Jaccard Coefficient Values')
plt.title('Jaccard Coefficient Values Pairwise Across Different Datasets')
plt.xticks(ticks=x, labels=conditions, rotation=45)

# Adding a legend below the plot
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4), ncol=3, fontsize='small')

# Adjust layout for better fit and readability
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### ivy Dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for each dataset
data_original = [0.6087, 0.2258, 0.1765, 0.25, 0.24, 0.1786, 0.32, 0.259, 0.259, 0.33]
data_2x = [0.21875, 0.09 , 0.069, 0.045, 0.1379, 0.1923, 0.1481, 0.4286, 0.1429, 0.1515]
data_4x = [0.433, 0.0625, 0.106, 0.094, 0.1111, 0.1389, 0.119, 0.225, 0.1458, 0.217]
data_8x = [0.2326, 0.087, 0.148, 0.1607, 0.22, 0.25, 0.115, 0.3913, 0.155, 0.155]
data_16x = [0.51, 0.1267, 0.1176, 0.1389, 0.1343, 0.125, 0.147, 0.1647, 0.585, 0.1764]

# X-coordinates for the conditions
conditions = ['Cond 1-2', 'Cond 1-3', 'Cond 1-4', 'Cond 1-5', 'Cond 2-3', 'Cond 2-4', 'Cond 2-5', 'Cond 3-4', 'Cond 3-5', 'Cond 4-5']
x = np.arange(len(conditions))

# Set the font properties
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12

# Create a plot with specified size
plt.figure(figsize=(8, 4))  # Adjusted width for more conditions

# Plotting each dataset
plt.plot(x, data_original, marker='o', label='Original')
plt.plot(x, data_2x, marker='o', label='2x')
plt.plot(x, data_4x, marker='o', label='4x')
plt.plot(x, data_8x, marker='o', label='8x')
plt.plot(x, data_16x, marker='o', label='16x')

# Adding labels and title
plt.xlabel('Condition Pairs')
plt.ylabel('Jaccard Coefficient Values')
plt.title('Jaccard Coefficient Values Pairwise Across Different Datasets')
plt.xticks(ticks=x, labels=conditions, rotation=45)

# Adding a legend below the plot
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1), ncol=3, fontsize='small')

# Adjust layout for better fit and readability
plt.tight_layout()

# Show the plot
plt.show()
